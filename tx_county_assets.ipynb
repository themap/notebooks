# %%
import pandas as pd
import geopandas as gpd

# %%
counties = gpd.read_file("../2_datastore/geos/tx_geo_counties_2017.geojson")
counties
county_list=counties['NAMELSAD10'].tolist()

# %%
counties.head()
# Out:
#    CBSAFP10 COUNTYFP10 CLASSFP10 MTFCC10  METDIVFP10  INTPTLON10  \
# 0   19100.0        113        H1   G4020     19124.0  -96.778424
# 1   13700.0        227        H1   G4020         NaN -101.438530
# 2       NaN        155        H1   G4020         NaN  -99.777427
# 3       NaN        153        H1   G4020         NaN -101.303274
# 4       NaN        043        H1   G4020         NaN -103.252458
#
#         NAMELSAD10 LSAD10 COUNTYNS10    AWATER10  GEOID10  CSAFP10  \
# 0    Dallas County     06   01383842  96696353.0    48113    206.0
# 1    Howard County     06   01383899   8841951.0    48227      NaN
# 2     Foard County     06   01383863   8514811.0    48155      NaN
# 3     Floyd County     06   01383862    983740.0    48153      NaN
# 4  Brewster County     06   01383807  22064004.0    48043      NaN
#
#         ALAND10  INTPTLAT10 FUNCSTAT10  STATEFP10    NAME10  \
# 0 -2.147484e+09   32.766987          A         48    Dallas
# ...

# %% [markdown]
# school districts
# schools
# hospitals
# pharmacies
# childcare centers
# police stations
# banks
# jails
# power plants
# places
# census tracts
# block groups
# zip codes
# voting districts
# senate districts
# house districts
# us house districts

# %%
# lister=[

# {"file", "tx_banks.geojson", "color": "blue", "name_property":"NAME"},
# {"file", "tx_universities.geojson", "color": "orange", "name_property":"LocationName"},
# {"file", "tx_childcare_centers.geojson", "color": "pink", "name_property":"Operation/Caregiver Name"},
    
# {"file", "tx_courts.geojson", "color": "brown", "name_property":"Court"},   
# {"file", "tx_Current_Schools.geojson", "color": "teal", "name_property":"School_Nam"},    
# {"file", "tx_fire_stations.geojson", "color": "red", "name_property":"Name"},      
# {"file", "tx_hospitals.geojson", "color": "yellow", "name_property":"NAME"},      
# {"file", "tx_police_stations.geojson", "blue": "orange", "name_property":"Name"},  
# {"file", "tx_jails.geojson", "color": "black", "name_property":"name"},  
# {"file", "tx_pharmacies.geojson", "color": "red", "name_property":"Name"},  
# {"file", "tx_private_schools.geojson", "color": "purple", "name_property":"name"},     
# {"file", "tx_power_plants.geojson", "color": "orange", "name_property":"Plant_Name"},   
    
# {"file", "tx_places.geojson", "color": "orange", "name_property":"NAME"}, 
# {"file", "tx_tracts_2017.geojson", "color": "dark green", "name_property":"GEOID"},    
# {"file", "tx_block_groups_2017.geojson", "color": "blue", "name_property":"GEOID"},
# {"file", "tx_zip_codes.geojson", "color": "red", "name_property":"zip code"},    
# {"file", "tx_voting_districts.geojson", "color": "purple", "name_property":"GEOID20"},   
# {"file", "tx_school_districts.geojson", "color": "green", "name_property":"NAME"},    
    
# {"file", "tx_counties.geojson", "color": "orange", "name_property":"NAMELSAD20"}, 
# {"file", "tx_house districts.json", "color": "purple", "name_property":"NAMELSAD"}, 
# {"file", "tx_senate districts.json.geojson", "color": "yellow", "name_property":"NAMELSAD"}, 
# {"file", "tx_us_house_districts.geojson ", "color": "navy blue", "name_property":"NAMELSAD"}, 
   
# ]

# %% [markdown]
# **Polygons**
# **County is a property**

# %%
# census_tracts= pd.read_csv("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_Current_Schools.csv")
# block_groups= pd.read_csv("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_Current_Schools.csv")
# voting_districts= pd.read_csv("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_Current_Schools.csv")
# courts= pd.read_csv("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_Current_Schools.csv")
# hospitals= pd.read_csv("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_Current_Schools.csv")
# schools = pd.read_csv("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_Current_Schools.csv")
# universities= pd.read_csv("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_Current_Schools.csv")

# %% [markdown]
# **Polygons**
# **Geospatial Match**

# %%
# school_districts=gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_school_districts.geojson")


# senate_districts=gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_school_districts.geojson")
# house_districts=gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_school_districts.geojson")
# us house_districts=gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_school_districts.geojson")

# places=gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_school_districts.geojson")
# jails=gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_school_districts.geojson")

# power plants=gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_school_districts.geojson")
# fire stations=gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_school_districts.geojson")
# police stations=gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_school_districts.geojson")


# childcare=gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_school_districts.geojson")
# pharmacies=gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_school_districts.geojson")
# banks=gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_school_districts.geojson")

# %% [markdown]
# zip_codes

# %%
zip_codes=gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_zip_codes.geojson")
for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    county_zips = gpd.sjoin(zip_codes, this_county_gdf, op='intersects')
    county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_zips.geojson", driver='GeoJSON')

# %% [markdown]
# universities

# %%
universities = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_colleges_2.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    county_zips = gpd.sjoin(universities, this_county_gdf, op='intersects')
    if county_zips.empty == False:
        county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_colleges.geojson", driver='GeoJSON')

# %% [markdown]
# banks

# %%
banks = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_banks.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    county_zips = gpd.sjoin(banks, this_county_gdf, op='intersects')
    if county_zips.empty == False:
        county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_banks.geojson", driver='GeoJSON')

# %% [markdown]
# schools

# %%
schools = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_Current_Schools.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    county_zips = gpd.sjoin(schools, this_county_gdf, op='intersects')
    if county_zips.empty == False:
        county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_public_schools.geojson", driver='GeoJSON')

# %% [markdown]
# private_schools

# %%
private_schools = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_private_schools.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    county_zips = gpd.sjoin(private_schools, this_county_gdf, op='intersects')
    if county_zips.empty == False:
        county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_private_schools.geojson", driver='GeoJSON')

# %% [markdown]
# jails

# %%
jails = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_jails.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    county_zips = gpd.sjoin(jails, this_county_gdf, op='intersects')
    if county_zips.empty == False:
        county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_jails.geojson", driver='GeoJSON')

# %% [markdown]
# power_plants

# %%
power_plants = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_power_plants.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    county_zips = gpd.sjoin(power_plants, this_county_gdf, op='intersects')
    if county_zips.empty == False:
        county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_power_plants.geojson", driver='GeoJSON')

# %% [markdown]
# fire_stations

# %%
fire_stations = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_fire_stations.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    county_zips = gpd.sjoin(fire_stations, this_county_gdf, op='intersects')
    if county_zips.empty == False:
        county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_fire_stations.geojson", driver='GeoJSON')

# %% [markdown]
# police_stations

# %%
police_stations = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_police_stations.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    county_zips = gpd.sjoin(police_stations, this_county_gdf, op='intersects')
    if county_zips.empty == False:
        county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_police_stations.geojson", driver='GeoJSON')

# %% [markdown]
# places

# %%
places = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_places_2018.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    county_zips = gpd.sjoin(places, this_county_gdf, op='intersects')
    if county_zips.empty == False:
        county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_places.geojson", driver='GeoJSON')

# %% [markdown]
# school_districts

# %%
school_districts = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_school_districts.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    county_zips = gpd.sjoin(school_districts, this_county_gdf, op='intersects')
    if county_zips.empty == False:
        county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_school_districts.geojson", driver='GeoJSON')

# %% [markdown]
# childcare_centers

# %%
childcare_centers = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_childcare_centers.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    county_zips = gpd.sjoin(childcare_centers, this_county_gdf, op='intersects')
    if county_zips.empty == False:
        county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_childcare_centers.geojson", driver='GeoJSON')

# %% [markdown]
# pharmacies

# %%
pharmacies = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_pharmacies.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    county_zips = gpd.sjoin(pharmacies, this_county_gdf, op='intersects')
    if county_zips.empty == False:
        county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_pharmacies.geojson", driver='GeoJSON')

# %% [markdown]
# hospitals

# %%
hospitals = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_hospitals.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    county_zips = gpd.sjoin(hospitals, this_county_gdf, op='intersects')
    if county_zips.empty == False:
        county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_hospitals.geojson", driver='GeoJSON')

# %% [markdown]
# house_districts

# %%
house_districts = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_house districts.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    county_zips = gpd.sjoin(house_districts, this_county_gdf, op='intersects')
    if county_zips.empty == False:
        county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_house_districts.geojson", driver='GeoJSON')

# %% [markdown]
# senate_districts

# %%
senate_districts = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_senate districts.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    county_zips = gpd.sjoin(senate_districts, this_county_gdf, op='intersects')
    if county_zips.empty == False:
        county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_senate_districts.geojson", driver='GeoJSON')

# %% [markdown]
# us_house_districts

# %%
us_house_districts = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_us_house_districts.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    county_zips = gpd.sjoin(us_house_districts, this_county_gdf, op='intersects')
    if county_zips.empty == False:
        county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_us_house_districts.geojson", driver='GeoJSON')

# %% [markdown]
# counties

# %%
us_house_districts = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_counties.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    this_county_gdf.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_boundary.geojson", driver='GeoJSON')

# %% [markdown]
# census_tracts

# %%
census_tracts = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_tracts_2017.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    this_countyfp = this_county_gdf.iloc[0]['COUNTYFP10']
    this_county_tracts = census_tracts[census_tracts['COUNTYFP']==this_countyfp]
    this_county_tracts.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_census_tracts.geojson", driver='GeoJSON')
    print(this_countyfp)
    
    
#     county_zips = gpd.sjoin(census_tracts, this_county_gdf, op='intersects')
#     if county_zips.empty == False:
#         county_zips.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_census_tracts.geojson", driver='GeoJSON')
# Out:
# 113
# 227
# 155
# 153
# 043
# 159
# 231
# 351
# 427
# 271
# 087
# 451
# 083
# 039
# 289
# 131
# 279
# 343
# 423
# 239
# 325
# 483
# 111
# 059
# 277
# 099
# 165
# 259
# 347
# 331
# 209
# 489
# 251
# 383
# 479
# 417
# 037
# 415
# 261
# 425
# 359
# 441
# 269
# 033
# 471
# 429
# 117
# 393
# 457
# 465
# 049
# 367
# 201
# 505
# 387
# 255
# 363
# 173
# 419
# 499
# 107
# 391
# 053
# 431
# 339
# 405
# 379
# 355
# 237
# 437
# 063
# 041
# 361
# 089
# 371
# 079
# 369
# 161
# 495
# 485
# 179
# 413
# 197
# 453
# 171
# 501
# 149
# 463
# 185
# 467
# 447
# 145
# 181
# 139
# 191
# 125
# 455
# 389
# 315
# 443
# 305
# 283
# 241
# 253
# 069
# 469
# 273
# 045
# 077
# 321
# 047
# 399
# 065
# 291
# 287
# 189
# 029
# 169
# 337
# 461
# 193
# 151
# 115
# 127
# 293
# 233
# 299
# 377
# 133
# 403
# 481
# 401
# 439
# 285
# 075
# 215
# 257
# 341
# 327
# 137
# 409
# 445
# 105
# 225
# 473
# 081
# 475
# 449
# 281
# 207
# 317
# 013
# 211
# 205
# 503
# 051
# 199
# 177
# 311
# 143
# 167
# 223
# 309
# 313
# 307
# 129
# ...

# %% [markdown]
# census_block_groups

# %%
block_groups = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_block_groups_2017.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    this_countyfp = this_county_gdf.iloc[0]['COUNTYFP10']
    this_county_blocks = block_groups[block_groups['COUNTYFP']==this_countyfp]
    this_county_blocks.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_block_groups.geojson", driver='GeoJSON')

# %% [markdown]
# voting_districts

# %%
voting_districts = gpd.read_file("d:\\dropbox\\themap\\data\\states\\tx\\_uploader\\tx_voting_districts.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    this_countyfp = this_county_gdf.iloc[0]['COUNTYFP10']
    this_county_voting_precincts = voting_districts[voting_districts['COUNTYFP20']==this_countyfp]
    this_county_voting_precincts.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_voting_districts.geojson", driver='GeoJSON')

# %% [markdown]
# 2020 election

# %%
results = gpd.read_file("h:\\themap_datastore\\precincts-with-results\\tx_results.geojson")

for c in county_list:
    this_county_gdf = counties[counties['NAMELSAD10']==c]
    this_countyfp = this_county_gdf.iloc[0]['COUNTYFP10']
    this_county_results = results[results['GEOID'].str.startswith('48' + this_countyfp)]
    this_county_results.to_file("c:\\users\\robert\\desktop\\tx_county_files\\" + c +"_2020_election_results.geojson", driver='GeoJSON')

# %%
def upload_file(my_path, my_file, row, state, token):
        tourmap = {
        'Title' : state + row["title"],
        'Description' : row['description'] + state,
        #'Logo' : row['Logo'],
        #'WebsiteUrl' : row['WebsiteUrl'],
        'Handle' : state + "_"+ row['handle'],
        'IsListed' : True,
        'EditPermissionType' : "0", # 0 - Just Me, 2 - Link Shared, 3 - Everyone 
        'ViewPermissionType' : "3",
        }
        print('-------------------------')
        print('Generating map : /'+tourmap['Handle'])
        tourmap = themap.map.create_map(tourmap,token)
        layer = {
            'IsVisible' : True,
            'Name' : row["key"],
            'TourMapID' : tourmap["ID"],
            'Type' : 'common',
            'IsShowProperties':True,
            'VisibleProperties':"NAME,STATEFP,STUSPS",
            #sourceURL
        }
        layer = themap.layer.create_layer(layer,token)
        layer = themap.layer.import_file(os.path.join(my_path, my_file),"NAME",tourmap["ID"],layer["ID"],token)
        style = themap.layer.get_default_style()
        style["common"]["common-width"] = 1
        style["common"]["common-color"] = "#0000ff"
        layer["GLStyle"] = json.dumps(style)
        themap.layer.update_layer(layer,token)
        sourceLayer = layer["GLSource"]
        print('Source Layer Created : '+sourceLayer)

        print('Map generated : /'+tourmap['Handle'])
        # themap.common.generate_screenshot(tourmap,token)
        print('-------------------------')
