# %%
import themap

# %%
token = themap.common.get_token()
# Out:
# --------Login to themap---------
# Enter username: themapdallas@gmail.com
# Password:········

# %%
lister=[]

for i in range(6683, 7786):
    lister.append(i)
    
# lister.append(6409)
# lister.append(6410)
# lister.append(6411)
# lister.append(6412)
# lister.append(6413)

# %%
lister
# Out:
# [6683,
#  6684,
#  6685,
#  6686,
#  6687,
#  6688,
#  6689,
#  6690,
#  6691,
#  6692,
#  6693,
#  6694,
#  6695,
#  6696,
#  6697,
#  6698,
#  6699,
#  6700,
#  6701,
#  6702,
#  6703,
#  6704,
#  6705,
#  6706,
#  6707,
#  6708,
#  6709,
#  6710,
#  6711,
#  6712,
#  6713,
#  6714,
#  6715,
#  6716,
#  6717,
#  6718,
#  6719,
#  6720,
#  6721,
#  6722,
#  6723,
#  6724,
#  6725,
#  6726,
#  6727,
#  6728,
#  6729,
#  6730,
#  6731,
#  6732,
#  6733,
#  6734,
#  6735,
#  6736,
#  6737,
#  6738,
#  6739,
#  6740,
#  6741,
#  6742,
#  6743,
#  6744,
#  6745,
#  6746,
#  6747,
#  6748,
#  6749,
#  6750,
#  6751,
#  6752,
#  6753,
#  6754,
#  6755,
#  6756,
#  6757,
#  6758,
#  6759,
#  6760,
#  6761,
#  6762,
#  6763,
#  6764,
#  6765,
#  6766,
#  6767,
#  6768,
#  6769,
#  6770,
#  6771,
#  6772,
#  6773,
#  6774,
#  6775,
#  6776,
#  6777,
#  6778,
#  6779,
#  6780,
#  6781,
#  6782,
#  6783,
#  6784,
#  6785,
#  6786,
#  6787,
#  6788,
#  6789,
#  6790,
#  6791,
#  6792,
#  6793,
# ...

# %%
for l in lister:
    themap.map.delete_map(l, token)
# Out:
# Deleting Map : 6683
# Deleting Map : 6684
# Deleting Map : 6685
# Deleting Map : 6686
# Deleting Map : 6687
# Deleting Map : 6688
# Deleting Map : 6689
# Deleting Map : 6690
# Deleting Map : 6691
# Deleting Map : 6692
# Deleting Map : 6693
# Deleting Map : 6694
# Deleting Map : 6695
# Deleting Map : 6696
# Deleting Map : 6697
# Deleting Map : 6698
# Deleting Map : 6699
# Deleting Map : 6700
# Deleting Map : 6701
# Deleting Map : 6702
# Deleting Map : 6703
# Deleting Map : 6704
# Deleting Map : 6705
# Deleting Map : 6706
# Deleting Map : 6707
# Deleting Map : 6708
# Deleting Map : 6709
# Deleting Map : 6710
# Deleting Map : 6711
# Deleting Map : 6712
# Deleting Map : 6713
# Deleting Map : 6714
# Deleting Map : 6715
# Deleting Map : 6716
# Deleting Map : 6717
# Deleting Map : 6718
# Deleting Map : 6719
# Deleting Map : 6720
# Deleting Map : 6721
# Deleting Map : 6722
# Deleting Map : 6723
# Deleting Map : 6724
# Deleting Map : 6725
# Deleting Map : 6726
# Deleting Map : 6727
# ...
