# %%
import pandas as pd
import geopandas as gpd

# %%
councils = gpd.read_file("https://mapfiles.blob.core.windows.net/map-files/DallasCityCouncils.geojson")
councils
# Out:
#     COUNCIL  DISTRICT               COUNCILPER          SHAPE_Leng  \
# 0         1         1             Scott Griggs   88541.30425390000
# 1         2         2             Adam Medrano  234255.36543100001
# 2         3         3       Vonciel Jones Hill  363222.33848500001
# 3         4         4        Dwaine R. Caraway  119105.55074700000
# 4         5         5            Rick Callahan  122534.44093200000
# 5         6         6         Monica R. Alonzo  454785.61478599999
# 6         7         7         Carolyn R. Davis  209464.64494800000
# 7         8         8           Tennell Atkins  339121.71318999998
# 8         9         9           Sheffie Kadane  722940.48823899997
# 9        10        10              Jerry Allen  108025.98382300000
# 10       11        11             Lee Kleinman  142358.33060099999
# 11       12        12            Sandy Greyson  108020.78707700000
# 12       13        13  Jennifer Staubach Gates  198681.53374600000
# ...
