# %%
import themap

# %% [markdown]
# **from a file**

# %%
with open("c:\\users\\robert\\desktop\\tx_assets_handles.txt") as f:
    content = f.readlines()
handles = [x.strip() for x in content] 
handles
# Out:
# ['anderson-county_banks_tx',
#  'anderson-county_banks_tx-2',
#  'anderson-county_banks_tx-2',
#  'anderson-county_banks_tx_2',
#  'anderson-county_block_groups_2_tx_2',
#  'anderson-county_banks_tx-2',
#  'anderson-county_block_groups_tx',
#  'anderson-county_banks_tx-2',
#  'anderson-county_block_groups_tx-2',
#  'anderson-county_census_tracts_tx',
#  'anderson-county_childcare_centers_tx',
#  'anderson-county_fire_stations_tx',
#  'anderson-county_hospitals_tx',
#  'anderson-county_jails_tx',
#  'anderson-county_pharmacies_tx',
#  'anderson-county_police_stations_tx',
#  'andrews-county_banks_tx',
#  'andrews-county_block_groups_tx',
#  'andrews-county_census_tracts_tx',
#  'andrews-county_childcare_centers_tx',
#  'andrews-county_banks_tx-2',
#  'andrews-county_block_groups_tx-2',
#  'andrews-county_census_tracts_tx-2',
#  'andrews-county_childcare_centers_tx-2',
#  'andrews-county_banks_tx-2',
#  'andrews-county_block_groups_tx-2',
#  'andrews-county_census_tracts_tx-2',
# ...

# %% [markdown]
# **from files**

# %%
files = os.listdir("c:\\users\\robert\\desktop\\tx_county_files")
for f in files:
    handles.append(f[:-8])

# %% [markdown]
# **from jupyter**

# %%
handles=[
'anderson-county_block_groups_2_tx_2',
'anderson-county_banks_tx-2'
]

# %% [markdown]
# **show handles**

# %%
for h in handles:
    print("\"" + h + "\",")
# Out:
# "anderson-county_banks_tx",
# "anderson-county_banks_tx-2",
# "anderson-county_banks_tx-2",
# "anderson-county_banks_tx_2",
# "anderson-county_block_groups_2_tx_2",
# "anderson-county_banks_tx-2",
# "anderson-county_block_groups_tx",
# "anderson-county_banks_tx-2",
# "anderson-county_block_groups_tx-2",
# "anderson-county_census_tracts_tx",
# "anderson-county_childcare_centers_tx",
# "anderson-county_fire_stations_tx",
# "anderson-county_hospitals_tx",
# "anderson-county_jails_tx",
# "anderson-county_pharmacies_tx",
# "anderson-county_police_stations_tx",
# "andrews-county_banks_tx",
# "andrews-county_block_groups_tx",
# "andrews-county_census_tracts_tx",
# "andrews-county_childcare_centers_tx",
# "andrews-county_banks_tx-2",
# "andrews-county_block_groups_tx-2",
# "andrews-county_census_tracts_tx-2",
# "andrews-county_childcare_centers_tx-2",
# "andrews-county_banks_tx-2",
# "andrews-county_block_groups_tx-2",
# "andrews-county_census_tracts_tx-2",
# ...

# %%
token = themap.common.get_token()

# %%
tourmap = {
'Title':'Census Block Groups in Rusk County, TX',
'Handle' : "rusk-county_block_groups_tx",
    "Layers":None,
    "DynaLayers":None,
    "TileLayers":None,
}

themap.common.generate_screenshot(tourmap, token)
