# %%
import geopandas as gpd

# %%
colleges = gpd.read_file("c:\\users\\robert\\desktop\\us_college_campus_shapes.geojson")
#print(colleges.columns.tolist())
colleges

colleges['center'] = colleges.centroid
colleges.drop(columns=['geometry'], inplace=True)
colleges.rename(columns={'center':'geometry'}, inplace=True)



# centers=colleges[['Name', 'description','icon', 'WEBSITE', 'TOT_ENROLL', 'TOT_EMP','UNIQUEID', 'ADDRESS', 'CITY', 'STATE', 'ZIP', 'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY', 'COUNTYFIPS','center']]
colleges.to_file("c:\\users\\robert\\desktop\\us_college_centers_2.geojson", driver='GeoJSON')

# %%
# centers = gpd.read_file("c:\\users\\robert\\desktop\\us_colleges_2.geojson",engine='python')
# centers
tx_colleges=colleges[colleges['STATE']=='TX']
tx_colleges.to_file("c:\\users\\robert\\desktop\\tx_colleges_2.geojson", driver='GeoJSON')
