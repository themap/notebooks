# %%
#https://wikipedia.readthedocs.io/en/latest/code.html#api
#https://towardsdatascience.com/wikipedia-api-for-python-241cfae09f1c

# %%
# !pip3 install wikipediaapi

# %%
import wikipedia-api
wiki_wiki = wikipedia-api.Wikipedia('en')
page_py = wiki_wiki.page('List_of_county_courthouses_in_Texas')
page_py
# Out:
#   File "<ipython-input-3-5da12accce32>", line 1
#     import wikipedia-api
#                     ^
# SyntaxError: invalid syntax

# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.3

# %%
# !pip install wikipedia
# Out:
# ...
#   Stored in directory: C:\Users\Robert\AppData\Local\pip\Cache\wheels\87\2a\18\4e471fd96d12114d16fe4a446d00c3b38fb9efcb744bd31f4a
# Successfully built wikipedia
# ...

# %%
import wikipedia
#print(wikipedia.search("Coronavirus"))
#https://towardsdatascience.com/wikipedia-api-for-python-241cfae09f1c


cts = wikipedia.page("List_of_county_courthouses_in_Texas")
print(cts.images)
# Out:
# ['https://upload.wikimedia.org/wikipedia/commons/0/0a/1914_Nueces_County_Courthouse_3.jpg', 'https://upload.wikimedia.org/wikipedia/commons/6/69/1915_Taylor_County_Courthouse_in_2015.jpg', 'https://upload.wikimedia.org/wikipedia/commons/6/63/20070429_Tarrant_County_Courthouse.JPG', 'https://upload.wikimedia.org/wikipedia/commons/6/69/Anderson_courthouse_tx_2010.jpg', 'https://upload.wikimedia.org/wikipedia/commons/8/89/Andrews_County_Courthouse%2C_Andrews%2C_Texas.jpg', 'https://upload.wikimedia.org/wikipedia/commons/6/6d/Angelina_county_tx_courthouse_2015.jpg', 'https://upload.wikimedia.org/wikipedia/commons/f/fb/Angleton_TX_Brazoria_county_courthouse_DSC_6280_ad.JPG', 'https://upload.wikimedia.org/wikipedia/commons/5/50/Angleton_TX_Old_Brazoria_county_courthouse_DSC_6265_ad.JPG', 'https://upload.wikimedia.org/wikipedia/commons/7/78/Another_photo%2C_Van_Zandt_County%2C_TX%2C_Courthouse_IMG_5621.JPG', 'https://upload.wikimedia.org/wikipedia/commons/c/c5/Aransas_county_courthouse_2014
# ...

# %%
print(cts.links)
# Out:
# ['1915 Taylor County Courthouse', '1919 King County Courthouse (Texas)', '1966 Dallas County Courthouse (Texas)', 'Abilene, Texas', 'Albany, Texas', 'Alfred Giles (architect)', 'Alice, Texas', 'Alpine, Texas', 'Amarillo, Texas', 'Anahuac, Texas', 'Anderson, Texas', 'Anderson County, Texas', 'Anderson County Courthouse (Texas)', 'Andrews, Texas', 'Andrews County, Texas', 'Andrews County Courthouse (Texas)', 'Angelina County, Texas', 'Angelina County Courthouse (Texas)', 'Angleton, Texas', 'Anson, Texas', 'Aransas County, Texas', 'Aransas County Courthouse (Texas)', 'Archer City, Texas', 'Archer County, Texas', 'Archer County Courthouse and Jail', 'Armstrong County, Texas', 'Armstrong County Courthouse (Texas)', 'Art Deco architecture', 'Aspermont, Texas', 'Atascosa County, Texas', 'Atascosa County Courthouse', 'Athens, Texas', 'Austin, Texas', 'Austin County, Texas', 'Austin County Courthouse (Texas)', 'Bailey County, Texas', 'Bailey County Courthouse (Texas)', 'Baird, Texas', 'Ballin
# ...

# %%
print(cts.content)
# Out:
# This is a list of county courthouses in the state of Texas, both current and former.
#
#
# == List ==
# Key
#
#
# == See also ==
# List of United States federal courthouses in Texas
#
#
# == References ==

# %%
print(cts.html())
# Out:
# <div class="mw-parser-output"><div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">Wikimedia list article</div>
# <p>This is a list of county courthouses in the state of Texas, both current and former.
# </p>
# <h2><span class="mw-headline" id="List">List</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=List_of_county_courthouses_in_Texas&amp;action=edit&amp;section=1" title="Edit section: List">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <table class="noprint infobox" id="GeoGroup" style="width: 23em; font-size: 88%; line-height: 1.5em">
#
# <tbody><tr>
# <td><b>Map all coordinates using:</b> <a class="external text" href="//tools.wmflabs.org/osm4wiki/cgi-bin/wiki/wiki-osm.pl?project=en&amp;article=List_of_county_courthouses_in_Texas">OpenStreetMap</a>&#160;
# </td></tr>
# <tr>
# ...

# %%
aud = wikipedia.page('Audie_Murphy_American_Cotton_Museum')
print(cts.summary)
# Out:
# This is a list of county courthouses in the state of Texas, both current and former.

# %%
# !pip install wikipedia

# %%
import wikipedia

print(wikipedia.page("List_of_county_courthouses_in_Texas").tables)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-77303bbcecc7> in <module>
#       1 import wikipedia
#       2
# ----> 3 print(wikipedia.page("List_of_county_courthouses_in_Texas").tables)
#
# AttributeError: 'WikipediaPage' object has no attribute 'tables'
